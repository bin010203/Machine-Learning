# %% [markdown]
# <a href="https://colab.research.google.com/github/bin010203/Machine-Learning/blob/main/A1_06_2%E8%AA%BF%E6%95%B4ETA_%E7%B7%9A%E6%80%A7%E5%9B%9E%E6%AD%B8%E7%9A%84%E4%BF%82%E6%95%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 實作06：利用梯度下降法求簡單線性回歸的係數

# %% [markdown]
# ### (0)掛載雲端硬碟

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### (1)import必要的套件

# %%
import numpy as np
from IPython import display
import matplotlib.pyplot as plt
import matplotlib.font_manager as plt_font
twfont1 = plt_font.FontProperties(fname="/content/drive/MyDrive/Colab Notebooks/kaiu.ttf")

# %% [markdown]
# ### (2)將原始資料分為訓練資料集和驗證資料集

# %%
#由SalesVolume.csv檔案載入資料集
data= np.loadtxt("/content/drive/MyDrive/Colab Notebooks/SalesVolume.csv",delimiter=",")

# %%
data
# Out:
# array([[ 24.,  22.,  15.,   4.,   9.,  20.,   5.,   3.,  17.,  19.,  13.,
#          10.,  12.,  11.,  16.,  27.,  16.,  16.,   6.,  20.],
#        [591., 543., 410., 310., 319., 520., 338., 330., 501., 508., 399.,
#         331., 390., 390., 431., 660., 409., 430., 323., 524.]])

# %%
data_x=data[0]#第1列為廣告推播次數
data_y=data[1]#第2列為商品銷售數量
#訓練資料集12筆
train_x=data_x[:12]
train_y=data_y[:12]
#驗證資料集8筆
valid_x=data_x[12:]
valid_y=data_y[12:]

# %%
data_x
# Out:
# array([24., 22., 15.,  4.,  9., 20.,  5.,  3., 17., 19., 13., 10., 12.,
#        11., 16., 27., 16., 16.,  6., 20.])

# %%
train_x
# Out:
# array([24., 22., 15.,  4.,  9., 20.,  5.,  3., 17., 19., 13., 10.])

# %%
valid_x
# Out:
# array([12., 11., 16., 27., 16., 16.,  6., 20.])

# %% [markdown]
# ### (3)隨機初始化偏值b，權重w
# ### 重新訓練由此開始 Run After

# %%
b=np.random.rand()
w=np.random.rand()
print("b = ",b ," w = ",w)
# Out:
# b =  0.9448891341840656  w =  0.19892181810100618

# %% [markdown]
# ## (4)定義迴歸模型的線性函數

# %%
def F(x):
  return b+w*x

# %% [markdown]
# ## (5)定義損失函數LOSS Funcation

# %%
# L=1/2*(y-y^)**2
def Loss(x,y):
  return 0.5*np.sum((y-F(x))**2)

# %% [markdown]
# ## (6)設定學習率和權重更新次數

# %%
# ETA=0.0001 #學習率加更大

# %%
ETA=0.007#學習率
#儲存學習的狀態
Step_Loss=[]
Step_b=[]
Step_w=[]

# %% [markdown]
# ## (7)開始訓練模型

# %%
# epoch 訓練的回合, ETA 學習率
for epoch in range(20000):
  b=b-ETA*np.sum(F(train_x)-train_y)
  w=w-ETA*np.sum((F(train_x)-train_y)*train_x)
            #跑100次才印一次,epoch從0開始,故+1,印太多會降低效率
  if epoch%100==99:
    current_loss=Loss(train_x,train_y)
    print("訓練次數:",epoch+1,"\nb:",b,"\nw:",w,
          "\n損失函數:",current_loss)
    Step_Loss.append(current_loss)
    Step_b.append(b)
    Step_w.append(w)
    #display.clear_output(wait=True)
# Out:
# 訓練次數: 100
# b: -1.3383033237749127e+123
# w: -2.120388739588726e+124
# 損失函數: 6.194141004981014e+251
# 訓練次數: 200
# b: -1.042235666894618e+246
# w: -1.6513033576331324e+247
# 損失函數: inf
# 訓練次數: 300
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 400
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 500
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 600
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 700
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 800
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 900
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 1000
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 1100
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 1200
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 1300
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 1400
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 1500
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 1600
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 1700
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 1800
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 1900
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 2000
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 2100
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 2200
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 2300
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 2400
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 2500
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 2600
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 2700
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 2800
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 2900
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 3000
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 3100
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 3200
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 3300
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 3400
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 3500
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 3600
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 3700
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 3800
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 3900
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 4000
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 4100
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 4200
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 4300
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 4400
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 4500
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 4600
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 4700
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 4800
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 4900
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 5000
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 5100
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 5200
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 5300
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 5400
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 5500
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 5600
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 5700
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 5800
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 5900
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 6000
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 6100
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 6200
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 6300
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 6400
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 6500
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 6600
# b: nan
# w: nan
# 損失函數:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: overflow encountered in square
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:87: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in add
# nan
# 訓練次數: 6700
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 6800
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 6900
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 7000
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 7100
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 7200
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 7300
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 7400
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 7500
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 7600
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 7700
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 7800
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 7900
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 8000
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 8100
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 8200
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 8300
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 8400
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 8500
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 8600
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 8700
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 8800
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 8900
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 9000
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 9100
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 9200
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 9300
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 9400
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 9500
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 9600
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 9700
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 9800
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 9900
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 10000
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 10100
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 10200
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 10300
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 10400
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 10500
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 10600
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 10700
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 10800
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 10900
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 11000
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 11100
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 11200
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 11300
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 11400
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 11500
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 11600
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 11700
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 11800
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 11900
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 12000
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 12100
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 12200
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 12300
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 12400
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 12500
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 12600
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 12700
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 12800
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 12900
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 13000
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 13100
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 13200
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 13300
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 13400
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 13500
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 13600
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 13700
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 13800
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 13900
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 14000
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 14100
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 14200
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 14300
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 14400
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 14500
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 14600
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 14700
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 14800
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 14900
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 15000
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 15100
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 15200
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 15300
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 15400
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 15500
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 15600
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 15700
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 15800
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 15900
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 16000
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 16100
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 16200
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 16300
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 16400
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 16500
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 16600
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 16700
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 16800
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 16900
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 17000
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 17100
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 17200
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 17300
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 17400
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 17500
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 17600
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 17700
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 17800
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 17900
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 18000
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 18100
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 18200
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 18300
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 18400
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 18500
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 18600
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 18700
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 18800
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 18900
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 19000
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 19100
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 19200
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 19300
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 19400
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 19500
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 19600
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 19700
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 19800
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 19900
# b: nan
# w: nan
# 損失函數: nan
# 訓練次數: 20000
# b: nan
# w: nan
# 損失函數: nan

# %% [markdown]
# ### (8)畫圖檢查模型訓練結果

# %%
plt.figure(figsize=(9,6))
plt.title("訓練模型和數據關係圖",
          fontproperties=twfont1,fontsize=20) 
plt.xlabel("x資料",fontproperties=twfont1,fontsize=20) 
plt.ylabel("y資料",fontproperties=twfont1,fontsize=20)
x=np.linspace(0,30, 2000)
plt.plot(x, F(x),label="模型函數")
plt.plot(train_x, train_y, 'go',label="訓練資料集")
plt.plot(valid_x, valid_y, 'ro',label="驗證資料集")
plt.legend(prop=twfont1)
plt.show()

# %% [markdown]
# ### (9)觀察Loss值隨訓練次數的變化

# %%
plt.figure(figsize=(9,6))
plt.title("Loss隨訓練次數的變化",fontproperties=twfont1,fontsize=20) 
plt.xlabel("訓練次數(x100)",fontproperties=twfont1,fontsize=20) 
plt.ylabel("Loss值",fontproperties=twfont1,fontsize=20)
plt.plot(Step_Loss,":o")
plt.show()

# %% [markdown]
# ### (10)比較訓練好的迴歸模型函數在訓練資料集和驗證資料集的每筆平均Loss值

# %%
print("訓練資料集對回歸模型的每筆平均Loss值",
      Loss(train_x, train_y)/np.size(train_x))
print("驗證資料集對回歸模型的每筆平均Loss值",
      Loss(valid_x, valid_y)/np.size(valid_x))
# Out:
# 訓練資料集對回歸模型的每筆平均Loss值 nan
# 驗證資料集對回歸模型的每筆平均Loss值 nan

# %%
I stop Runall
# Out:
#   File "<ipython-input-104-dc36fd94116c>", line 1
#     I stop Runall
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### (11)動畫顯示偏值b和權重w的移動路徑

# %%
for i in range(len(Step_b)):
    plt.figure(figsize=(6,6))
    plt.title("動畫顯示迴歸係數的移動路徑",
              fontproperties=twfont1,fontsize=20)
    plt.xlabel("b",fontproperties=twfont1,fontsize=20) 
    plt.ylabel("w",fontproperties=twfont1,fontsize=20) 
    plt.xlim(np.min(np.array([Step_b,Step_w])),
             np.max(np.array([Step_b,Step_w])))
    plt.ylim(np.min(np.array([Step_b,Step_w])),
             np.max(np.array([Step_b,Step_w])))
    plt.scatter(Step_b[:i], Step_w[:i], s=20,color='r')
    plt.pause(0.1)
    display.clear_output(wait=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-105-8ecca1e84d73> in <module>()
#       6     plt.ylabel("w",fontproperties=twfont1,fontsize=20)
#       7     plt.xlim(np.min(np.array([Step_b,Step_w])),
# ----> 8              np.max(np.array([Step_b,Step_w])))
#       9     plt.ylim(np.min(np.array([Step_b,Step_w])),
#      10              np.max(np.array([Step_b,Step_w])))
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in xlim(*args, **kwargs)
#    1394     if not args and not kwargs:
#    1395         return ax.get_xlim()
# -> 1396     ret = ax.set_xlim(*args, **kwargs)
#    1397     return ret
#    1398
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in set_xlim(self, left, right, emit, auto, xmin, xmax)
#    3182
#    3183         self._process_unit_info(xdata=(left, right))
# -> 3184         left = self._validate_converted_limits(left, self.convert_xunits)
#    3185         right = self._validate_converted_limits(right, self.convert_xunits)
#    3186
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in _validate_converted_limits(self, limit, convert)
#    3099             if (isinstance(converted_limit, Real)
#    3100                     and not np.isfinite(converted_limit)):
# -> 3101                 raise ValueError("Axis limits cannot be NaN or Inf")
#    3102             return converted_limit
#    3103
#
# ValueError: Axis limits cannot be NaN or Inf

# %%
for i in range(len(Step_b)):
    plt.figure(figsize=(12,12))
    plt.title("動畫顯示迴歸係數的移動路徑",
              fontproperties=twfont1,fontsize=20)
    plt.xlabel("b",fontproperties=twfont1,fontsize=20) 
    plt.ylabel("w",fontproperties=twfont1,fontsize=20) 
    # X軸、Y軸刻度取array([Step_b,Step_w])的極值
    plt.xlim(np.min(np.array(Step_b)),
             np.max(np.array(Step_b)))
    plt.ylim(np.min(np.array(Step_w)),
             np.max(np.array(Step_w)))
    plt.scatter(Step_b[:i], Step_w[:i], s=10,color='r')
    plt.grid('k-', alpha=0.8)
    plt.pause(0.2)
    display.clear_output(wait=True)

# %% [markdown]
# ### (12)顯示迴歸係數在損失函數等高線分布圖的移動路徑

# %%
#取b和w的網格範圍
b=np.linspace(0,300,200)
w=np.linspace(-30,70,200)
#計算每一個網格點對應的損失函數值
L=np.zeros((200,200)) 
for i in range(200):
  for j in range(200):
    L[j][i]=0.5*np.sum((train_y-(b[i]+w[j]*train_x))**2)
#鋪設網格
b,w=np.meshgrid(b,w)
# 開啟繪圖區域
plt.figure(figsize=(14,14))
CS=plt.contour(b,w,L,100)
plt.clabel(CS,inline=1,fontsize=10)
plt.scatter(Step_b[0:], Step_w[0:], s=20,color='r')
plt.title('等高線圖',fontproperties=twfont1)
plt.show()

# %% [markdown]
# # *******************************

# %% [markdown]
# # 再重新調整 ETA 更小,看結果如何?
# ### (3)隨機初始化偏值b，權重w

# %%
b=np.random.rand()
w=np.random.rand()
print("b = ",b ," w = ",w)
# Out:
# b =  0.07617343069053073  w =  0.9489945221786965

# %% [markdown]
# ## (4)定義迴歸模型的線性函數

# %%
def F(x):
  return b+w*x

# %% [markdown]
# ## (5)定義損失函數LOSS Funcation

# %%
# L=1/2*(y-y^)**2
def Loss(x,y):
  return 0.5*np.sum((y-F(x))**2)

# %% [markdown]
# ## (6)設定學習率和權重更新次數

# %%
# ETA=0.0001 #學習率加更小

# %%
ETA=0.00006#學習率
#儲存學習的狀態
Step_Loss=[]
Step_b=[]
Step_w=[]

# %% [markdown]
# ## (7)開始訓練模型

# %%
# epoch 訓練的回合, ETA 學習率
for epoch in range(20000):
  b=b-ETA*np.sum(F(train_x)-train_y)
  w=w-ETA*np.sum((F(train_x)-train_y)*train_x)
            #跑100次才印一次,epoch從0開始,故+1,印太多會降低效率
  if epoch%100==99:
    current_loss=Loss(train_x,train_y)
    print("訓練次數:",epoch+1,"\nb:",b,"\nw:",w,
          "\n損失函數:",current_loss)
    Step_Loss.append(current_loss)
    Step_b.append(b)
    Step_w.append(w)
    #display.clear_output(wait=True)
# Out:
# 訓練次數: 100
# b: 5.30174862504445
# w: 27.536787579161114
# 損失函數: 77737.8420349555
# 訓練次數: 200
# b: 8.892593333247586
# w: 27.325244733358474
# 損失函數: 75582.70072787322
# 訓練次數: 300
# b: 12.429650808433713
# w: 27.11687017509103
# 損失函數: 73491.63953255977
# 訓練次數: 400
# b: 15.913726752903033
# w: 26.911616856197526
# 損失函數: 71462.75311424825
# 訓練次數: 500
# b: 19.345614776207224
# w: 26.709438023680327
# 損失函數: 69494.19279299382
# 訓練次數: 600
# b: 22.726096600432378
# w: 26.51028762485426
# 損失函數: 67584.16485676146
# 訓練次數: 700
# b: 26.055942238261288
# w: 26.314120296856608
# 損失函數: 65730.92892703228
# 訓練次數: 800
# b: 29.33591016836834
# w: 26.12089135631431
# 損失函數: 63932.79637300583
# 訓練次數: 900
# b: 32.5667475081872
# w: 25.93055678916586
# 損失函數: 62188.12877295449
# 訓練次數: 1000
# b: 35.74919018409081
# w: 25.743073240635734
# 損失函數: 60495.33642132667
# 訓練次數: 1100
# b: 38.883963099021976
# w: 25.558398005358946
# 損失函數: 58852.87688023971
# 訓練次數: 1200
# b: 41.97178029761332
# w: 25.376489017653498
# 損失函數: 57259.253574041795
# 訓練次數: 1300
# b: 45.0133451288335
# w: 25.19730484193864
# 損失函數: 55713.01442566296
# 訓練次數: 1400
# b: 48.00935040619775
# w: 25.020804663296538
# 損失函數: 54212.750533511644
# 訓練次數: 1500
# b: 50.9604785655779
# w: 24.84694827817543
# 損失函數: 52757.09488771278
# 訓練次數: 1600
# b: 53.867401820649214
# w: 24.67569608523192
# 損失函數: 51344.72112451593
# 訓練次數: 1700
# b: 56.730782316008465
# w: 24.507009076310556
# 損失函數: 49974.342317739734
# 訓練次數: 1800
# b: 59.55127227799837
# w: 24.340848827558457
# 損失函數: 48644.70980615108
# 訓練次數: 1900
# b: 62.32951416327311
# w: 24.177177490673042
# 損失函數: 47354.61205571041
# 訓練次數: 2000
# b: 65.06614080513828
# w: 24.015957784280914
# 損失函數: 46102.87355564662
# 訓練次數: 2100
# b: 67.76177555769901
# w: 23.85715298544579
# 損失函數: 44888.35374735548
# 訓練次數: 2200
# b: 70.41703243784852
# w: 23.700726921303687
# 損失函數: 43709.94598514612
# 訓練次數: 2300
# b: 73.03251626513038
# w: 23.546643960823427
# 損失函數: 42566.57652788782
# 訓練次數: 2400
# b: 75.60882279950515
# w: 23.39486900669051
# 損失函數: 41457.20356063907
# 訓練次數: 2500
# b: 78.14653887705403
# w: 23.24536748731256
# 損失函數: 40380.81624536705
# 訓練次數: 2600
# b: 80.64624254364931
# w: 23.0981053489446
# 損失函數: 39336.43379989263
# 訓練次數: 2700
# b: 83.10850318662293
# w: 22.953049047932144
# 損失函數: 38323.1046042215
# 訓練次數: 2800
# b: 85.53388166446253
# w: 22.81016554307063
# 損失函數: 37339.90533344765
# 訓練次數: 2900
# b: 87.92293043456478
# w: 22.669422288079208
# 損失函數: 36385.94011643838
# 訓練次數: 3000
# b: 90.27619367907548
# w: 22.530787224187254
# 損失函數: 35460.33971953486
# 訓練次數: 3100
# b: 92.59420742884417
# w: 22.394228772832008
# 損失函數: 34562.26075452406
# 訓練次數: 3200
# b: 94.87749968552238
# w: 22.259715828465517
# 損失函數: 33690.88491016074
# 訓練次數: 3300
# b: 97.12659054183287
# w: 22.127217751469356
# 損失函數: 32845.418206538736
# 訓練次數: 3400
# b: 99.34199230003725
# w: 21.996704361175503
# 損失函數: 32025.09027163287
# 訓練次數: 3500
# b: 101.52420958862928
# w: 21.868145928991694
# 損失函數: 31229.153639351498
# 訓練次數: 3600
# b: 103.67373947728018
# w: 21.7415131716298
# 損失函數: 30456.883068460702
# 訓練次數: 3700
# b: 105.79107159006192
# w: 21.61677724443564
# 損失函數: 29707.57488175931
# 訓練次數: 3800
# b: 107.87668821697503
# w: 21.493909734818654
# 損失函數: 28980.546324902425
# 訓練次數: 3900
# b: 109.93106442380511
# w: 21.372882655780067
# 損失函數: 28275.134944289843
# 訓練次數: 4000
# b: 111.95466816033479
# w: 21.25366843953793
# 損失函數: 27590.697983451526
# 訓練次數: 4100
# b: 113.9479603669338
# w: 21.136239931247673
# 損失函數: 26926.61179738125
# 訓練次數: 4200
# b: 115.91139507955302
# w: 21.020570382816747
# 損失函數: 26282.271284283896
# 訓練次數: 4300
# b: 117.84541953314567
# w: 20.90663344681188
# 損失函數: 25657.089334218977
# 訓練次數: 4400
# b: 119.75047426353947
# w: 20.794403170457603
# 損失函數: 25050.496294138113
# 訓練次數: 4500
# b: 121.62699320778226
# w: 20.68385398972468
# 損失函數: 24461.93944882885
# 訓練次數: 4600
# b: 123.47540380298561
# w: 20.574960723507086
# 損失函數: 23890.88251729163
# 訓練次數: 4700
# b: 125.29612708368697
# w: 20.467698567886206
# 損失函數: 23336.805164091627
# 訓練次數: 4800
# b: 127.08957777775382
# w: 20.36204309048095
# 損失函數: 22799.20252523966
# 訓練次數: 4900
# b: 128.85616440085116
# w: 20.257970224882488
# 損失函數: 22277.584748170386
# 訓練次數: 5000
# b: 130.59628934949387
# w: 20.155456265172372
# 損失函數: 21771.47654539871
# 訓練次數: 5100
# b: 132.31034899270566
# w: 20.054477860522752
# 損失函數: 21280.41676144744
# 訓練次數: 5200
# b: 133.9987337623044
# w: 19.95501200987747
# 損失函數: 20803.957952651865
# 訓練次數: 5300
# b: 135.66182824183582
# w: 19.857036056712854
# 損失函數: 20341.665979458157
# 訓練次數: 5400
# b: 137.30001125417436
# w: 19.76052768387695
# 損失函數: 19893.119610844347
# 訓練次數: 5500
# b: 138.9136559478124
# w: 19.665464908506095
# 損失函數: 19457.91014050311
# 訓練次數: 5600
# b: 140.5031298818568
# w: 19.571826077017587
# 損失函數: 19035.641014436897
# 訓練次數: 5700
# b: 142.06879510975173
# w: 19.479589860177445
# 損失函數: 18625.927469626222
# 訓練次數: 5800
# b: 143.61100826174862
# w: 19.38873524824194
# 損失函數: 18228.396183441142
# 訓練次數: 5900
# b: 145.13012062613947
# w: 19.299241546172006
# 損失函數: 17842.68493347751
# 訓練次數: 6000
# b: 146.62647822927445
# w: 19.211088368919214
# 損失函數: 17468.442267507187
# 訓練次數: 6100
# b: 148.10042191438032
# w: 19.12425563678249
# 損失函數: 17105.327183241963
# 訓練次數: 6200
# b: 149.55228741919768
# w: 19.038723570834332
# 損失函數: 16753.008817619375
# 訓練次數: 6300
# b: 150.9824054524573
# w: 18.95447268841544
# 損失函數: 16411.166145326708
# 訓練次數: 6400
# b: 152.39110176920855
# w: 18.871483798696993
# 損失函數: 16079.487686289543
# 訓練次數: 6500
# b: 153.77869724502054
# w: 18.78973799830933
# 損失函數: 15757.671221857432
# 訓練次數: 6600
# b: 155.1455079490723
# w: 18.70921666703608
# 損失函數: 15445.42351942832
# 訓練次數: 6700
# b: 156.4918452161476
# w: 18.629901463572764
# 損失函數: 15142.460065260973
# 訓練次數: 6800
# b: 157.81801571755074
# w: 18.55177432134909
# 損失函數: 14848.50480523201
# 訓練次數: 6900
# b: 159.12432153096134
# w: 18.474817444413603
# 損失函數: 14563.28989330089
# 訓練次數: 7000
# b: 160.41106020924227
# w: 18.399013303380155
# 損失函數: 14286.555447453984
# 訓練次數: 7100
# b: 161.67852484821614
# w: 18.32434463143501
# 損失函數: 14018.049312905609
# 訓練次數: 7200
# b: 162.9270041534279
# w: 18.25079442040378
# 損失函數: 13757.526832339527
# 訓練次數: 7300
# b: 164.15678250590636
# w: 18.17834591687724
# 損失函數: 13504.75062298229
# 訓練次數: 7400
# b: 165.36814002694143
# w: 18.10698261839526
# 損失函數: 13259.490360304817
# 訓練次數: 7500
# b: 166.56135264188993
# w: 18.036688269687808
# 損失函數: 13021.522568155524
# 訓練次數: 7600
# b: 167.73669214302726
# w: 17.96744685897228
# 損失函數: 12790.630415133242
# 訓練次數: 7700
# b: 168.89442625145645
# w: 17.899242614306342
# 損失函數: 12566.603517014933
# 訓練次數: 7800
# b: 170.03481867808983
# w: 17.83205999999534
# 損失函數: 12349.237745057924
# 訓練次數: 7900
# b: 171.1581291837184
# w: 17.765883713053547
# 損失函數: 12138.33504000185
# 訓練次數: 8000
# b: 172.2646136381798
# w: 17.700698679718442
# 損失函數: 11933.703231601205
# 訓練次數: 8100
# b: 173.3545240786416
# w: 17.636490052017148
# 損失函數: 11735.155863523622
# 訓練次數: 8200
# b: 174.42810876700997
# w: 17.57324320438438
# 損失函數: 11542.512023454796
# 訓練次數: 8300
# b: 175.48561224647995
# w: 17.510943730330947
# 損失函數: 11355.596178254766
# 訓練次數: 8400
# b: 176.52727539723762
# w: 17.449577439162272
# 損失函數: 11174.238014015751
# 訓練次數: 8500
# b: 177.55333549132888
# w: 17.389130352745937
# 損失函數: 10998.27228087547
# 訓練次數: 8600
# b: 178.56402624670457
# w: 17.329588702327793
# 損失函數: 10827.538642445048
# 訓練次數: 8700
# b: 179.55957788045816
# w: 17.270938925395654
# 損失函數: 10661.88152971361
# 訓練次數: 8800
# b: 180.5402171612647
# w: 17.213167662589974
# 損失函數: 10501.149999296998
# 訓練次數: 8900
# b: 181.50616746103472
# w: 17.15626175466087
# 損失函數: 10345.197595901273
# 訓練次數: 9000
# b: 182.4576488057942
# w: 17.100208239470664
# 損失函數: 10193.882218875578
# 訓練次數: 9100
# b: 183.39487792580255
# w: 17.04499434904135
# 損失函數: 10047.065992733009
# 訓練次數: 9200
# b: 184.31806830492016
# w: 16.99060750664624
# 損失函數: 9904.615141521163
# 訓練次數: 9300
# b: 185.22743022923552
# w: 16.937035323945285
# 損失函數: 9766.399866928334
# 訓練次數: 9400
# b: 186.12317083496495
# w: 16.88426559816319
# 損失函數: 9632.294230013918
# 訓練次數: 9500
# b: 187.00549415563472
# w: 16.83228630930983
# 損失函數: 9502.176036455325
# 訓練次數: 9600
# b: 187.87460116855596
# w: 16.78108561744234
# 損失函數: 9375.926725207084
# 訓練次數: 9700
# b: 188.73068984060384
# w: 16.730651859968173
# 損失函數: 9253.431260470381
# 訓練次數: 9800
# b: 189.57395517331025
# w: 16.68097354898859
# 損失函數: 9134.578026874906
# 訓練次數: 9900
# b: 190.4045892472823
# w: 16.63203936868192
# 損失函數: 9019.258727777054
# 訓練次數: 10000
# b: 191.22278126595472
# w: 16.583838172725994
# 損失函數: 8907.368286582292
# 訓練次數: 10100
# b: 192.0287175986865
# w: 16.53635898175926
# 損失函數: 8798.804751001562
# 訓練次數: 10200
# b: 192.82258182321308
# w: 16.48959098087984
# 損失函數: 8693.469200154328
# 訓練次數: 10300
# b: 193.6045547674616
# w: 16.443523517182125
# 損失函數: 8591.265654433959
# 訓練次數: 10400
# b: 194.37481455074078
# w: 16.39814609733018
# 損失函數: 8492.100988053018
# 訓練次數: 10500
# b: 195.13353662431223
# w: 16.353448385167646
# 損失函數: 8395.884844189057
# 訓練次數: 10600
# b: 195.8808938113563
# w: 16.309420199363252
# 損失函數: 8302.529552653139
# 訓練次數: 10700
# b: 196.61705634633748
# w: 16.266051511091746
# 損失函數: 8211.9500500067
# 訓練次數: 10800
# b: 197.34219191378025
# w: 16.223332441749527
# 損失函數: 8124.063802053455
# 訓練次數: 10900
# b: 198.05646568646577
# w: 16.181253260704406
# 損失函數: 8038.790728635823
# 訓練次數: 11000
# b: 198.76004036305423
# w: 16.1398043830792
# 損失函數: 7956.0531306676385
# 訓練次數: 11100
# b: 199.4530762051451
# w: 16.098976367568486
# 損失函數: 7875.775619336283
# 訓練次數: 11200
# b: 200.1357310737817
# w: 16.058759914287982
# 損失函數: 7797.8850474099145
# 訓練次數: 11300
# b: 200.8081604654095
# w: 16.01914586265623
# 損失函數: 7722.310442587185
# 訓練次數: 11400
# b: 201.47051754729483
# w: 15.980125189307998
# 損失函數: 7648.982942828792
# 訓練次數: 11500
# b: 202.12295319241358
# w: 15.94168900603891
# 損失函數: 7577.835733611801
# 訓練次數: 11600
# b: 202.76561601381806
# w: 15.903828557780848
# 損失函數: 7508.803987049492
# 訓練次數: 11700
# b: 203.3986523984875
# w: 15.866535220607757
# 損失函數: 7441.82480282166
# 訓練次數: 11800
# b: 204.02220654067324
# w: 15.82980049977121
# 損失函數: 7376.837150861001
# 訓練次數: 11900
# b: 204.6364204747425
# w: 15.79361602776552
# 損失函數: 7313.781815743862
# 訓練次數: 12000
# b: 205.24143410753237
# w: 15.757973562421714
# 損失函數: 7252.60134273428
# 訓練次數: 12100
# b: 205.83738525021727
# w: 15.722864985030158
# 損失函數: 7193.239985432445
# 訓練次數: 12200
# b: 206.4244096497
# w: 15.688282298491261
# 損失函數: 7135.643654979683
# 訓練次數: 12300
# b: 207.00264101953297
# w: 15.654217625493832
# 損失函數: 7079.759870773783
# 訓練次數: 12400
# b: 207.5722110703749
# w: 15.620663206720838
# 損失函數: 7025.537712649812
# 訓練次數: 12500
# b: 208.13324953999256
# w: 15.587611399081922
# 損失函數: 6972.927774482627
# 訓練次數: 12600
# b: 208.68588422281277
# w: 15.555054673972482
# 損失函數: 6921.882119169033
# 訓練次數: 12700
# b: 209.23024099903182
# w: 15.522985615558733
# 損失函數: 6872.354234948481
# 訓練次數: 12800
# b: 209.76644386328798
# w: 15.491396919088588
# 損失函數: 6824.2989930225185
# 訓練次數: 12900
# b: 210.2946149529058
# w: 15.46028138922772
# 損失函數: 6777.67260643434
# 訓練次數: 13000
# b: 210.81487457571703
# w: 15.429631938420597
# 損失函數: 6732.432590170951
# 訓練次數: 13100
# b: 211.32734123746383
# w: 15.399441585276094
# 損失函數: 6688.537722451775
# 訓練次數: 13200
# b: 211.8321316687928
# w: 15.369703452977218
# 損失函數: 6645.9480071681655
# 訓練次數: 13300
# b: 212.329360851844
# w: 15.340410767714726
# 損失函數: 6604.624637439736
# 訓練次數: 13400
# b: 212.81914204644156
# w: 15.311556857144161
# 損失函數: 6564.529960254409
# 訓練次數: 13500
# b: 213.30158681589256
# w: 15.28313514886601
# 損失函數: 6525.627442159655
# 訓練次數: 13600
# b: 213.77680505239874
# w: 15.255139168928645
# 損失函數: 6487.881635974044
# 訓練次數: 13700
# b: 214.24490500208856
# w: 15.227562540353647
# 損失函數: 6451.258148488433
# 訓練次數: 13800
# b: 214.70599328967285
# w: 15.200398981683282
# 損失函數: 6415.72360912762
# 訓練次數: 13900
# b: 215.1601749427332
# w: 15.173642305549642
# 損失函數: 6381.2456395437075
# 訓練次數: 14000
# b: 215.60755341564402
# w: 15.14728641726534
# 損失函數: 6347.792824113662
# 訓練次數: 14100
# b: 216.04823061313857
# w: 15.121325313435205
# 損失函數: 6315.334681313999
# 訓練次數: 14200
# b: 216.4823069135205
# w: 15.095753080588837
# 損失函數: 6283.841635946681
# 訓練次數: 14300
# b: 216.9098811915283
# w: 15.070563893833619
# 損失函數: 6253.284992190764
# 訓練次數: 14400
# b: 217.33105084085733
# w: 15.045752015527915
# 損失函數: 6223.636907455363
# 訓練次數: 14500
# b: 217.7459117963444
# w: 15.021311793974132
# 損失函數: 6194.870367010041
# 訓練次數: 14600
# b: 218.15455855581925
# w: 14.997237662131385
# 損失函數: 6166.9591593695795
# 訓練次數: 14700
# b: 218.5570842016309
# w: 14.973524136347384
# 損失函數: 6139.8778524105555
# 訓練次數: 14800
# b: 218.95358042184841
# w: 14.95016581510942
# 損失函數: 6113.601770198125
# 訓練次數: 14900
# b: 219.34413753114754
# w: 14.927157377813915
# 損失函數: 6088.106970501806
# 訓練次數: 15000
# b: 219.7288444913812
# w: 14.904493583554569
# 損失函數: 6063.370222979848
# 訓練次數: 15100
# b: 220.10778893184437
# w: 14.88216926992852
# 損失函數: 6039.368988012169
# 訓練次數: 15200
# b: 220.48105716923368
# w: 14.860179351860486
# 損失函數: 6016.081396162755
# 訓練次數: 15300
# b: 220.84873422730985
# w: 14.838518820444424
# 損失函數: 5993.486228252628
# 訓練次數: 15400
# b: 221.21090385626363
# w: 14.817182741802625
# 損失函數: 5971.5628960253935
# 訓練次數: 15500
# b: 221.56764855179304
# w: 14.796166255961868
# 損失函數: 5950.291423387651
# 訓練次數: 15600
# b: 221.91904957389426
# w: 14.775464575746389
# 損失函數: 5929.652428207142
# 訓練次數: 15700
# b: 222.26518696537119
# w: 14.755072985687464
# 損失函數: 5909.62710465221
# 訓練次數: 15800
# b: 222.60613957006768
# w: 14.734986840949308
# 損失函數: 5890.197206056247
# 訓練次數: 15900
# b: 222.9419850508272
# w: 14.715201566271036
# 損失函數: 5871.345028291722
# 訓練次數: 16000
# b: 223.27279990718216
# w: 14.695712654924568
# 損失函數: 5853.053393638578
# 訓練次數: 16100
# b: 223.59865949277966
# w: 14.676515667688017
# 損失函數: 5835.305635132213
# 訓練次數: 16200
# b: 223.9196380325461
# w: 14.65760623183452
# 損失函數: 5818.0855813768585
# 訓練次數: 16300
# b: 224.23580863959356
# w: 14.638980040136238
# 損失函數: 5801.37754181056
# 訓練次數: 16400
# b: 224.54724333187372
# w: 14.620632849883236
# 損失函數: 5785.166292408279
# 訓練次數: 16500
# b: 224.85401304858274
# w: 14.602560481917061
# 損失函數: 5769.4370618100265
# 訓練次數: 16600
# b: 225.1561876663197
# w: 14.584758819678802
# 損失函數: 5754.175517861514
# 訓練次數: 16700
# b: 225.45383601500274
# w: 14.567223808271446
# 損失函數: 5739.3677545550245
# 訓練次數: 16800
# b: 225.7470258935482
# w: 14.549951453536192
# 損失函數: 5725.0002793584845
# 訓練次數: 16900
# b: 226.03582408531298
# w: 14.532937821142713
# 損失函數: 5711.060000921381
# 訓練次數: 17000
# b: 226.3202963733074
# w: 14.51617903569294
# 損失函數: 5697.534217146178
# 訓練次數: 17100
# b: 226.600507555179
# w: 14.49967127983833
# 損失函數: 5684.410603614432
# 訓練次數: 17200
# b: 226.87652145797227
# w: 14.483410793410355
# 損失函數: 5671.677202357021
# 訓練次數: 17300
# b: 227.14840095266734
# w: 14.467393872564005
# 損失函數: 5659.322410958292
# 訓練次數: 17400
# b: 227.41620796850103
# w: 14.451616868934076
# 損失函數: 5647.334971984181
# 訓練次數: 17500
# b: 227.6800035070727
# w: 14.436076188804215
# 損失函數: 5635.703962724667
# 訓練次數: 17600
# b: 227.93984765624003
# w: 14.420768292288264
# 損失函數: 5624.418785241208
# 訓練次數: 17700
# b: 228.1957996038056
# w: 14.405689692523964
# 損失函數: 5613.469156710135
# 訓練次數: 17800
# b: 228.4479176509985
# w: 14.390836954878722
# 損失函數: 5602.845100053143
# 訓練次數: 17900
# b: 228.69625922575486
# w: 14.376206696167257
# 損失函數: 5592.536934846382
# 訓練次數: 18000
# b: 228.94088089579864
# w: 14.361795583880953
# 損失函數: 5582.53526849984
# 訓練次數: 18100
# b: 229.18183838152632
# w: 14.347600335428819
# 損失函數: 5572.830987699042
# 訓練次數: 18200
# b: 229.4191865686997
# w: 14.33361771738973
# 損失函數: 5563.415250101145
# 訓練次數: 18300
# b: 229.65297952094753
# w: 14.319844544775927
# 損失函數: 5554.27947627799
# 訓練次數: 18400
# b: 229.88327049208024
# w: 14.306277680307534
# 損失函數: 5545.415341898709
# 訓練次數: 18500
# b: 230.11011193822054
# w: 14.292914033697935
# 損失函數: 5536.814770144744
# 訓練次數: 18600
# b: 230.33355552975112
# w: 14.27975056094989
# 損失函數: 5528.469924350455
# 訓練次數: 18700
# b: 230.55365216308527
# w: 14.266784263662132
# 損失函數: 5520.373200862442
# 訓練次數: 18800
# b: 230.7704519722594
# w: 14.254012188346406
# 損失函數: 5512.517222111342
# 訓練次數: 18900
# b: 230.98400434035298
# w: 14.24143142575472
# 損失函數: 5504.894829889447
# 訓練次數: 19000
# b: 231.19435791073704
# w: 14.22903911021666
# 損失函數: 5497.499078828358
# 訓練次數: 19100
# b: 231.4015605981546
# w: 14.216832418986634
# 損失函數: 5490.323230070468
# 訓練次數: 19200
# b: 231.6056595996339
# w: 14.204808571600935
# 損失函數: 5483.360745128677
# 訓練次數: 19300
# b: 231.8067014052402
# w: 14.19296482924436
# 損失函數: 5476.605279928628
# 訓練次數: 19400
# b: 232.00473180866427
# w: 14.181298494126397
# 損失函數: 5470.050679028155
# 訓練次數: 19500
# b: 232.1997959176542
# w: 14.169806908866683
# 損失函數: 5463.690970008534
# 訓練次數: 19600
# b: 232.39193816428968
# w: 14.15848745588972
# 損失函數: 5457.520358032547
# 訓練次數: 19700
# b: 232.5812023151031
# w: 14.147337556828628
# 損失函數: 5451.533220564346
# 訓練次數: 19800
# b: 232.76763148104826
# w: 14.136354671937864
# 損失函數: 5445.724102246336
# 訓練次數: 19900
# b: 232.95126812732116
# w: 14.12553629951466
# 損失函數: 5440.087709928301
# 訓練次數: 20000
# b: 233.13215408303174
# w: 14.114879975329261
# 損失函數: 5434.61890784448

# %% [markdown]
# ### (8)畫圖檢查模型訓練結果

# %%
plt.figure(figsize=(9,6))
plt.title("訓練模型和數據關係圖",
          fontproperties=twfont1,fontsize=20) 
plt.xlabel("x資料",fontproperties=twfont1,fontsize=20) 
plt.ylabel("y資料",fontproperties=twfont1,fontsize=20)
x=np.linspace(0,30, 2000)
plt.plot(x, F(x),label="模型函數")
plt.plot(train_x, train_y, 'go',label="訓練資料集")
plt.plot(valid_x, valid_y, 'ro',label="驗證資料集")
plt.legend(prop=twfont1)
plt.show()

# %% [markdown]
# ### (9)觀察Loss值隨訓練次數的變化

# %%
plt.figure(figsize=(9,6))
plt.title("Loss隨訓練次數的變化",fontproperties=twfont1,fontsize=20) 
plt.xlabel("訓練次數(x100)",fontproperties=twfont1,fontsize=20) 
plt.ylabel("Loss值",fontproperties=twfont1,fontsize=20)
plt.plot(Step_Loss,":o")
plt.show()

# %% [markdown]
# ### (10)比較訓練好的迴歸模型函數在訓練資料集和驗證資料集的每筆平均Loss值

# %%
print("訓練資料集對回歸模型的每筆平均Loss值",
      Loss(train_x, train_y)/np.size(train_x))
print("驗證資料集對回歸模型的每筆平均Loss值",
      Loss(valid_x, valid_y)/np.size(valid_x))
# Out:
# 訓練資料集對回歸模型的每筆平均Loss值 452.88490898704003
# 驗證資料集對回歸模型的每筆平均Loss值 404.53283294810876

# %%
I stop Runall
# Out:
#   File "<ipython-input-117-dc36fd94116c>", line 1
#     I stop Runall
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### (11)動畫顯示偏值b和權重w的移動路徑

# %%
for i in range(len(Step_b)):
    plt.figure(figsize=(6,6))
    plt.title("動畫顯示迴歸係數的移動路徑",
              fontproperties=twfont1,fontsize=20)
    plt.xlabel("b",fontproperties=twfont1,fontsize=20) 
    plt.ylabel("w",fontproperties=twfont1,fontsize=20) 
    plt.xlim(np.min(np.array([Step_b,Step_w])),
             np.max(np.array([Step_b,Step_w])))
    plt.ylim(np.min(np.array([Step_b,Step_w])),
             np.max(np.array([Step_b,Step_w])))
    plt.scatter(Step_b[:i], Step_w[:i], s=20,color='r')
    plt.pause(0.1)
    display.clear_output(wait=True)

# %%
for i in range(len(Step_b)):
    plt.figure(figsize=(10,10))
    plt.title("動畫顯示迴歸係數的移動路徑",
              fontproperties=twfont1,fontsize=20)
    plt.xlabel("b",fontproperties=twfont1,fontsize=20) 
    plt.ylabel("w",fontproperties=twfont1,fontsize=20) 
    # X軸、Y軸刻度取array([Step_b,Step_w])的極值
    plt.xlim(np.min(np.array(Step_b)),
             np.max(np.array(Step_b)))
    plt.ylim(np.min(np.array(Step_w)),
             np.max(np.array(Step_w)))
    plt.scatter(Step_b[:i], Step_w[:i], s=10,color='r')
    plt.grid('k-', alpha=0.8)
    plt.pause(0.2)
    display.clear_output(wait=True)

# %% [markdown]
# ### (12)顯示迴歸係數在損失函數等高線分布圖的移動路徑

# %%
#取b和w的網格範圍
b=np.linspace(0,300,200)
w=np.linspace(-30,70,200)
#計算每一個網格點對應的損失函數值
L=np.zeros((200,200)) 
for i in range(200):
  for j in range(200):
    L[j][i]=0.5*np.sum((train_y-(b[i]+w[j]*train_x))**2)
#鋪設網格
b,w=np.meshgrid(b,w)
# 開啟繪圖區域
plt.figure(figsize=(14,14))
CS=plt.contour(b,w,L,100)
plt.clabel(CS,inline=1,fontsize=10)
plt.scatter(Step_b[0:], Step_w[0:], s=20,color='r')
plt.title('等高線圖',fontproperties=twfont1)
plt.show()
