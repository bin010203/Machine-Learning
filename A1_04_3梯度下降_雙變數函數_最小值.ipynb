# %% [markdown]
# <a href="https://colab.research.google.com/github/bin010203/Machine-Learning/blob/main/A1_04_3%E6%A2%AF%E5%BA%A6%E4%B8%8B%E9%99%8D_%E9%9B%99%E8%AE%8A%E6%95%B8%E5%87%BD%E6%95%B8_%E6%9C%80%E5%B0%8F%E5%80%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 實作04：利用梯度下降法逼近雙變數函數的最小值

# %% [markdown]
# ### (0)掛載雲端硬碟

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### (1)import必要的套件

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as plt_font
twfont1=plt_font.FontProperties(fname="/content/drive/MyDrive/Colab Notebooks/kaiu.ttf")

# %%
import sympy as sp
from sympy import S
from sympy.abc import x, y, z, t, a, b, c, d, R, r, h ,n 
from sympy.abc import alpha, beta, gamma, pi, eta

# %%
from  sympy  import  exp,  sin, cos, tan, sec
from  sympy  import  sqrt, log, plot, diff, integrate, limit

# %% [markdown]
# ### (2)定義雙變數函數f(x,y)=x<sup>2</sup>+y<sup>2</sup>學生可以自行修改)

# %%
f = 9*(x**2)+y**2
f
# Out:
# 9*x**2 + y**2

# %%
f1 = diff(f, x)
f1
# Out:
# 18*x

# %%
#9*(x**2)+y**2

# %%
def F(x,y):
    return 9*(x**2)+y**2

# %% [markdown]
# ### (3)定義雙變數函數的偏導函數fx=2x及fx=2y(學生可以自行修改)

# %%
# 18*x  # 2*y

# %%
def Fx(x,y):
    return 18*x
def Fy(x,y):
    return 2*y

# %% [markdown]
# ### (4)利用梯度下降找函數的極小值

# %%
#設定step_x、step_y用來儲存梯度下降每一步的座標
step_x=[]
step_y=[]
step_z=[]
#設定學習率，可以調大或調小，觀察梯度下降情況
ETA=0.02
#設定梯度下降的起點，可以改變不同位置，觀察梯度下降情況
x_point=-3
y_point=-5
counter = 0
while abs(Fx(x_point,y_point)) >= 0.0001 or abs(Fy(x_point,y_point)) >= 0.0001:
    step_x.append(x_point)
    step_y.append(y_point)
    step_z.append(F(x_point,y_point))
    #利用梯度下降，更新x_point和y_point
    x_point=x_point-ETA*Fx(x_point,y_point)
    y_point=y_point-ETA*Fy(x_point,y_point)
    counter += 1

# %%
 print("下降次數 = ",counter)
# Out:
# 下降次數 =  283

# %% [markdown]
# ### (5)鋪設繪圖的底圖網格

# %%
#產生橫軸、縱軸座標的數據點矩陣(在-5和5之間，間隔0.1)
x=np.arange(-5,5,0.1)
y=np.arange(-5,5,0.1)
#利用橫軸、縱軸座標的數據點鋪設網點
x,y=np.meshgrid(x,y)

# %% [markdown]
# ### (6)劃出曲面圖及梯度下降路徑

# %%
#開啟繪圖區域
fig=plt.figure(figsize=(16,12))
#設定為3D繪圖
ax=fig.gca(projection='3d')
#設定坐標軸範圍
ax.set_zlim(0,150)
ax.set_xlim(-5,5)
ax.set_ylim(-5,5)
#設定坐標軸說明文字
ax.set_xlabel('X軸',fontproperties=twfont1)
ax.set_ylabel('Y軸',fontproperties=twfont1)
ax.set_zlabel('Z軸',fontproperties=twfont1)
#畫出3D曲面,cmap為數值及色階對應方式,linewidth為線寬,antiliased=Fasle可以加快繪圖速度 
surf=ax.plot_surface(x,y,F(x,y),cmap="hot",alpha=0.1,antialiased=False)
# 畫出梯度修正路徑的點和線
ax.plot(step_x,step_y,step_z,"b:o",lw=1, ms=2);
# 顯示數值及色階對應方式,shrink設定colorbar長度為圖片高度的幾倍,預設值1.0,aspect設定colorbar寬、高比,預設值20
fig.colorbar(surf,shrink=0.5,aspect=5)
#elev=75設定視線和水平面的夾75度，azim=38設定立體圖順時針旋轉38度
ax.view_init(elev=70,azim=35)

# %%
#等高線圖

# %%
plt.figure(figsize = (10,10))
plt.title('等高線圖',fontproperties=twfont1,fontsize=20)
CS = plt.contour(x, y, F(x,y), 100)
plt.plot(step_x, step_y, "b-o")
plt.clabel(CS, inline=1, fontsize=14)
# Out:
# <a list of 188 text.Text objects>

# %%
#畫出3D曲面,cmap為數值及色階對應方式,linewidth為線寬,antiliased=Fasle可以加快繪圖速度 
#surf=ax.plot_surface(x,y,F(x,y),cmap="warm",alpha=0.2,antialiased=False)

# %% [markdown]
# supported values are 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r',
#
#  'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r',
#
#  'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r',
#
#   'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'oce...

# %%
#開啟繪圖區域
fig=plt.figure(figsize=(12,6))
#設定為3D繪圖
ax=fig.gca(projection='3d')
#設定坐標軸範圍
ax.set_zlim(0,150)
ax.set_xlim(-5,5)
ax.set_ylim(-5,5)
#設定坐標軸說明文字
ax.set_xlabel('X軸',fontproperties=twfont1)
ax.set_ylabel('Y軸',fontproperties=twfont1)
ax.set_zlabel('Z軸',fontproperties=twfont1)
#畫出3D曲面,cmap為數值及色階對應方式,linewidth為線寬,antiliased=Fasle可以加快繪圖速度 
surf=ax.plot_surface(x,y,F(x,y),cmap="nipy_spectral_r",alpha=0.6,antialiased=False)
# 畫出梯度修正路徑的點和線
ax.plot(step_x,step_y,step_z,"k:o");
# 顯示數值及色階對應方式,shrink設定colorbar長度為圖片高度的幾倍,預設值1.0,aspect設定colorbar寬、高比,預設值20
fig.colorbar(surf,shrink=0.5,aspect=5)
#elev=20設定視線和水平面的夾20度，azim=30設定立體圖順時針旋轉30度
ax.view_init(elev=50,azim=10)

# %%
#開啟繪圖區域
fig=plt.figure(figsize=(12,6))
#設定為3D繪圖
ax=fig.gca(projection='3d')
#設定坐標軸範圍
ax.set_zlim(0,150)
ax.set_xlim(-5,5)
ax.set_ylim(-5,5)
#設定坐標軸說明文字
ax.set_xlabel('X軸',fontproperties=twfont1)
ax.set_ylabel('Y軸',fontproperties=twfont1)
ax.set_zlabel('Z軸',fontproperties=twfont1)
#畫出3D曲面,cmap為數值及色階對應方式,linewidth為線寬,antiliased=Fasle可以加快繪圖速度 
surf=ax.plot_surface(x,y,F(x,y),cmap="gist_rainbow",alpha=0.6,antialiased=False)
# 畫出梯度修正路徑的點和線
ax.plot(step_x,step_y,step_z,"k:o");
# 顯示數值及色階對應方式,shrink設定colorbar長度為圖片高度的幾倍,預設值1.0,aspect設定colorbar寬、高比,預設值20
fig.colorbar(surf,shrink=0.5,aspect=5)
#elev=20設定視線和水平面的夾20度，azim=30設定立體圖順時針旋轉30度
ax.view_init(elev=70,azim=35)
